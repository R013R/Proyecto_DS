# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from lxml import etree
from datetime import date
from datetime import datetime
import seaborn as sns

# %%
url = requests.get('https://www.argenprop.com/casa-venta-localidad-capital-federal')
url.status_code
# Out:
# 200

# %%
#Se extrae la información del html

casas = BeautifulSoup(url.content, 'html.parser')
dom= etree.HTML(str(casas))

#Se extrae la ubicación

ubicacion = casas.find_all('p', attrs={"class":"card__address"})
ubicacion=[i.text for i in ubicacion]

#Se extrae la descripción base

descripcion_base = casas.find_all('h2', attrs={"class":"card__title"})
descripcion_base=[i.text for i in descripcion_base]

#Se extrae el área

area=dom.xpath('//ul[@class="card__main-features"]/li[1]/span')
area=[i.text for i in area]

#Se extraen los dormitorios

dormitorios=dom.xpath('//ul[@class="card__main-features"]/li[2]/span')
dormitorios=[i.text for i in dormitorios]

#Se extrae la antiguedad

antiguedad=dom.xpath('//ul[@class="card__main-features"]/li[3]/span')
antiguedad=[i.text for i in antiguedad]

#Se extrae el precio

precio = casas.find_all('p', attrs={'class':'card__price'})
precio=[i.text for i in precio]

#Se extrae la url

urls = casas.find_all('a', attrs={'class':'card'})
urls = [i.get('href') for i in urls]
urls=['https://www.argenprop.com'+i for i in urls]

# %%
#Se crea el dataframe y se tratan las columnas correspondientes

df = pd.DataFrame({'Descripción':descripcion_base,'Ubicación':ubicacion, 'Área':area, 'Dormitorios':dormitorios,'Antigüedad':antiguedad, 'Precio':precio, 'Link':urls})
df.Precio=df.Precio.str.replace('\n','').str.replace(' ','').str.replace('USD','USD  ').str.replace('.',',')
df.Ubicación=df.Ubicación.str.replace('\n','').str.strip(' ').str.strip('\n')
df.Área=df.Área.str.replace('\n','').str.strip(' ').str.strip('\n')
df.Antigüedad=df.Antigüedad.str.replace('\n','').str.strip(' ').str.strip('\n')
df.Dormitorios=df.Dormitorios.str.replace('\n','').str.strip(' ').str.strip('\n')
df['Fecha_obs']=date.today()

# %%
df
# Out:
#                                           Descripción  \
# 0   Excelente Chalet 5 Amb - Dependencias en 2 Pla...
# 1   Impecable casa de 4 ambientes en 3 plantas – G...
# 2   Importante Chalet 5 amb - Playroom - Dependenc...
# 3   Casa 4 Ambientes Patio/ Galería/ Quincho sobre...
# 4   Casa 6 amb sobre lote de 17,36 mtrs2 x 33,47 m...
# 5   Impecable casa de 4 ambientes en 3 plantas – G...
# 6   Casa en venta 8 ambientes -  Piscina - Garaje ...
# 7                                 Casa - Villa Devoto
# 8   Venta de Casa con Patio/Pileta/Quincho - Villa...
# 9   Venta de Casa 5 ambientes con oficina y deposi...
# 10  Venta - Casa 6 ambientes sobre lote propio de ...
# 11  Venta - Casa 4 Ambientes en 2 Plantas con Gara...
# 12  REGIA CASA . AMP LIVING COMEDOR. 2 DORMITORIOS...
# 13  Casa -  en venta, Gran potencial! a Mts de Jon...
# 14  Casa -  en venta, Gran potencial! a Mts de Jon...
# 15            VENTA DUEÑO DIRECTO -  CASA LOTE PROPIO
# 16                  Casa en venta en Villa del Parque
# 17                 Triplex 4 Ambientes - Villa Devoto
# 18  CASA DE ESTILO 5 AMB. BCON.GARAJE, PATIO,PISCINA.
# 19  CASA LOTE PROPIO 4 DORMITOR-PATIO-COCHERA-PARR...
#
#                                             Ubicación            Área  \
# 0                                 Emilio Lamarca 2754  240  m² cubie.
# 1                                       Argerich 3717  185  m² cubie.
# 2                                   Chivilcoy al 4480  625  m² cubie.
# 3                                      Pareja al 3800  200  m² cubie.
# 4                                Gualeguaychu al 3079  788  m² cubie.
# 5                                       Argerich 3717  185  m² cubie.
# 6                           Jose Pedro Varela al 3850  728  m² cubie.
# 7                                    Mercedes al 4900  300  m² cubie.
# 8                                     Navarro al 4800  230  m² cubie.
# 9                              Benito Juárez  al 2900  330  m² cubie.
# 10                               Gualeguaychu al 3014  164  m² cubie.
# 11                              Benito Juarez al 3400  156  m² cubie.
# 12                                     J Navarro 4700  140  m² cubie.
# 13                                 LOPEZ DE VEGA 1500  132  m² cubie.
# 14                                 NEMESIO TREJO 5100  132  m² cubie.
# 15                                Pje Calingasta 1800  175  m² cubie.
# 16                                  Pedro Lozano 3300  105  m² cubie.
# 17  TRIPLEX 4 amb/2 COCHERAS- SIN EXPENSAS-PARRILL...  158  m² cubie.
# 18                                Emilio Lamarca 4900  291  m² cubie.
# 19                                       Bazurco 3300  143  m² cubie.
#
#    Dormitorios  Antigüedad           Precio  \
# 0      4 dorm.     30 años     USD  465,000
# 1      3 dorm.     12 años     USD  370,000
# 2      4 dorm.  A Estrenar     USD  850,000
# 3      4 dorm.     18 años     USD  690,000
# 4      5 dorm.     30 años   USD  1,350,000
# 5      3 dorm.     12 años     USD  370,000
# 6      5 dorm.     35 años  Consultarprecio
# 7      4 dorm.      8 años     USD  595,000
# 8      4 dorm.     10 años     USD  400,000
# 9      4 dorm.     15 años     USD  430,000
# 10     4 dorm.     20 años     USD  350,000
# 11     3 dorm.     30 años     USD  245,000
# 12     2 dorm.     15 años     USD  235,000
# 13     3 dorm.     90 años     USD  158,000
# 14     3 dorm.     90 años     USD  158,000
# 15     3 dorm.       1 año     USD  329,000
# 16     3 dorm.  A Estrenar     USD  195,000
# 17     3 dorm.  A Estrenar     USD  495,000
# 18     3 dorm.     40 años     USD  315,000
# 19     4 dorm.     16 años     USD  200,000
#
#                                                  Link   Fecha_obs
# 0   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 1   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 2   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 3   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 4   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 5   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 6   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 7   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 8   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 9   https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 10  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 11  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 12  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 13  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 14  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 15  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 16  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 17  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 18  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20
# 19  https://www.argenprop.com/casa-en-venta-en-vil...  2024-01-20

# %%
siguiente='https://www.argenprop.com'+dom.xpath('//ul[@class="pagination pagination--links"]/li[contains(@class,"-next")]/a')[0].get('href')

# %%
ini=dom.xpath('//li[@class="pagination__page pagination__page--current"]/span')[0].text
ini=int(ini)

# %%
can=dom.xpath('//li[@class="pagination__page"][3]/a')[0].text
can=int(can)

# %%
l_descripcion=[]
l_ubicacion=[]
l_area=[]
l_dormitorios=[]
l_antiguedad=[]
l_precio=[]
l_urls=[]

# %%
siguiente='https://www.argenprop.com/casa-venta-localidad-capital-federal'
r=requests.get(siguiente)
casas = BeautifulSoup(r.content, 'html.parser')
dom= etree.HTML(str(casas))
can=dom.xpath('//li[@class="pagination__page"][3]/a')[0].text
can=int(can)
while True:
    r=requests.get(siguiente)
    if r.status_code==200:
        #Se extrae la información del html

        casas = BeautifulSoup(r.content, 'html.parser')
        dom= etree.HTML(str(casas))

        #Ubicación

        ubicacion = casas.find_all('p', attrs={"class":"card__address"})
        ubicacion=[i.text for i in ubicacion]
        l_ubicacion.extend(ubicacion)

        #Descripción base

        descripcion_base = casas.find_all('h2', attrs={"class":"card__title"})
        descripcion_base=[i.text for i in descripcion_base]
        l_descripcion.extend(descripcion_base)

        #Área

        area=dom.xpath('//ul[@class="card__main-features"]/li[1]/span')
        area=[i.text for i in area]
        l_area.extend(area)

        #Dormitorios

        dormitorios=dom.xpath('//ul[@class="card__main-features"]/li[2]/span')
        dormitorios=[i.text for i in dormitorios]
        l_dormitorios.extend(dormitorios)

        #Antigüedad

        antiguedad=dom.xpath('//ul[@class="card__main-features"]/li[3]/span')
        antiguedad=[i.text for i in antiguedad]
        l_antiguedad.extend(antiguedad)

        #Precio

        precio = casas.find_all('p', attrs={'class':'card__price'})
        precio=[i.text for i in precio]
        l_precio.extend(precio)

        #Url

        urls = casas.find_all('a', attrs={'class':'card'})
        urls = [i.get('href') for i in urls]
        urls=['https://www.argenprop.com'+i for i in urls]
        l_urls.extend(urls)
        
        ini=dom.xpath('//li[@class="pagination__page pagination__page--current"]/span')[0].text
        ini=int(ini)
    else:
        break
    print(ini,can)
    if ini==can:
        break
    siguiente='https://www.argenprop.com'+dom.xpath('//ul[@class="pagination pagination--links"]/li[contains(@class,"-next")]/a')[0].get('href')
# Out:
# 1 314
# 2 314
# 3 314
# 4 314
# 5 314
# 6 314
# 7 314
# 8 314
# 9 314
# 10 314
# 11 314
# 12 314
# 13 314
# 14 314
# 15 314
# 16 314
# 17 314
# 18 314
# 19 314
# 20 314
# 21 314
# 22 314
# 23 314
# 24 314
# 25 314
# 26 314
# 27 314
# 28 314
# 29 314
# 30 314
# 31 314
# 32 314
# 33 314
# 34 314
# 35 314
# 36 314
# 37 314
# 38 314
# 39 314
# 40 314
# 41 314
# 42 314
# 43 314
# 44 314
# 45 314
# 46 314
# 47 314
# 48 314
# 49 314
# 50 314
# 51 314
# 52 314
# 53 314
# 54 314
# 55 314
# 56 314
# 57 314
# 58 314
# 59 314
# 60 314
# 61 314
# 62 314
# 63 314
# 64 314
# 65 314
# 66 314
# 67 314
# 68 314
# 69 314
# 70 314
# 71 314
# 72 314
# 73 314
# 74 314
# 75 314
# 76 314
# 77 314
# 78 314
# 79 314
# 80 314
# 81 314
# 82 314
# 83 314
# 84 314
